# %%
import torch 
import numpy as np
import pandas as pd

# %%
data_input = pd.read_csv('BL--ExpressionData.csv', index_col=0)
train_data = pd.read_csv('/home/netra-mobile/Desktop/GNNLink-master/Data/Train_validation_test/hESC 500/Train_set.csv', index_col=0).values
test_data = pd.read_csv('/home/netra-mobile/Desktop/GNNLink-master/Data/Train_validation_test/hESC 500/Test_set.csv', index_col=0).values
tf = pd.read_csv('TF.csv', index_col=0)['index'].values.astype(np.int64)
tf = torch.from_numpy(tf)#.to(self.device)
target = pd.read_csv('Target.csv',index_col=0)['index'].values.astype(np.int64)
target = torch.from_numpy(target)#.to(self.device)

# %%
data_input
# Out:
#         H9_00hb4s_001  H9_00hb4s_002  H9_00hb4s_003  H9_00hb4s_004  \
# KIF21A       7.679538       7.914004       7.409868       6.226928
# DPH2         5.312810       5.041560       4.002452       6.894618
# FUS          5.281794       5.503217       5.938976       5.313464
# NKX3-1       0.000000       5.974976       0.000000       0.000000
# TRIM33       7.996107       5.104049       5.723665       1.845207
# ...               ...            ...            ...            ...
# GCA          5.415605       6.825231       7.441517       6.846669
# NOL11        8.318358       9.662753       6.790495       9.021283
# KRCC1        6.158881       2.744434       4.730438       0.000000
# TEAD4        4.951478       3.810594       2.249993       3.507437
# OXTR         4.480848       3.443538       1.969116       3.009541
#
#         H9_00hb4s_005  H9_00hb4s_006  H9_00hb4s_007  H9_00hb4s_008  \
# KIF21A       5.782105       6.329417       7.355231       6.617552
# ...

# %%
len(tf)
# Out:
# 410

# %%
pd.read_csv('TF.csv')
# Out:
#      Unnamed: 0      TF  index
# 0             0     FUS      2
# 1             1  NKX3-1      3
# 2             2  TRIM33      4
# 3             3   HOXB4      5
# 4             4    NONO      6
# ..          ...     ...    ...
# 405         405   STAT2    899
# 406         406   SNAI2    900
# 407         407  ANKRD1    901
# 408         408    NFIA    902
# 409         409   TEAD4    908
#
# [410 rows x 3 columns]

# %%
len(target)
# Out:
# 910
